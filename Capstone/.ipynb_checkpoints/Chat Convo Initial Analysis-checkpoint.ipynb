# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

# NLP Imports
import regex as re
from bs4 import BeautifulSoup
import string
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from textblob import TextBlob, Word
from sklearn.feature_extraction import text
from wordcloud import WordCloud, ImageColorGenerator
import spacy
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# Other Imports
import janitor
from datetime import datetime
from dateutil import parser

# Ignore warnings
import warnings
def ignore_warn(*args,**kwargs):
    pass
warnings.warn=ignore_warn

# %%
path = 'data/chats/sample_1.txt'

# %%
def read_history(file):
    string = open(file).read()
    new_str = re.sub('\[',"",string)
    new_str = re.sub('\]',"",string)
    #f = open('data/{}'.format(file), 'r')
    #f = open(file,'r') 
    # Every text message has the same format: date - sender: message. 
    messages = re.findall('(\d+/\d+/\d+, \d+:\d+:\d+ [A-Z]*) (.*?): (.*)', new_str)

    #Convert list to a dataframe and name the columns
    history = pd.DataFrame(messages,columns=['datetime','name','msg'])
    history['datetime'] = pd.to_datetime(history['datetime'],format="%d/%m/%y, %I:%M:%S %p")
    history['date'] = history['datetime'].apply(lambda x: x.date())

    # file is in the format 'WhatsApp Conversation with XXX.txt'
    history['conv_name'] = file[19:-4]

    return history

# %%
chat = read_history(path)

# %%
chat.columns
# Out:
# Index(['datetime', 'name', 'msg', 'date', 'conv_name'], dtype='object')

# %%
chat.shape
# Out:
# (121325, 5)

# %%
chat.drop(columns='conv_name')
chat.head()
# Out:
#              datetime name                                                msg  \
# 0 2018-03-21 09:47:16    👻  ‎Messages and calls are end-to-end encrypted. ...
# 1 2018-03-21 09:47:16   A.        Hello 👋 where have you been? You fell sick?
# 2 2018-03-21 10:03:35    👻  Hello, just taking some time off :) need to cl...
# 3 2018-04-12 11:19:34   A.                     Hey! What time is lunch later?
# 4 2018-04-12 11:19:36   A.                                              12pm?
#
#          date conv_name
# 0  2018-03-21
# 1  2018-03-21
# 2  2018-03-21
# 3  2018-04-12
# 4  2018-04-12

# %%
chat['msg'].value_counts()
# Out:
# ‎sticker omitted                                                                              18111
# ‎image omitted                                                                                 3383
# Ok                                                                                             1285
# Haha                                                                                            916
# :(                                                                                              510
#                                                                                               ...
# Btw is it not okay to tell my friends about allianz role ? Now im confused about privacy☹️        1
# All I know is that I love you                                                                     1
# Just arrived                                                                                      1
# And helpless                                                                                      1
# It should be in the 200-250k region                                                               1
# Name: msg, Length: 70299, dtype: int64

# %%
chat[chat['msg'].str.contains(r'^(?!.*sticker).*omitted')]
# Out:
#                   datetime name                    msg        date conv_name
# 195    2018-05-31 12:19:17    👻         ‎image omitted  2018-05-31
# 218    2018-06-06 19:08:23    👻         ‎image omitted  2018-06-06
# 286    2018-07-20 14:38:11   A.  ‎Contact card omitted  2018-07-20
# 497    2018-09-02 12:09:47   A.         ‎image omitted  2018-09-02
# 498    2018-09-02 12:09:47   A.         ‎image omitted  2018-09-02
# ...                    ...  ...                    ...         ...       ...
# 121184 2020-09-21 11:15:09   A.         ‎image omitted  2020-09-21
# 121239 2020-09-21 21:03:00   A.         ‎image omitted  2020-09-21
# 121318 2020-09-22 13:30:57   A.         ‎image omitted  2020-09-22
# 121319 2020-09-22 13:30:57   A.         ‎image omitted  2020-09-22
# 121320 2020-09-22 13:36:52   A.         ‎image omitted  2020-09-22
#
# [3590 rows x 5 columns]

# %%
index_omitted = chat[chat['msg'].str.match('^(?!.*sticker).*omitted')]
index_omitted_2 = chat[chat['msg'].str.contains(r'deleted this message|message was deleted|end-to-end encrypted')]

# %%
chat.drop(index=index_omitted.index,inplace=True)
chat.drop(index=index_omitted_2.index,inplace=True)
chat.reset_index(inplace = True)

# %%
chat['msg'].value_counts()
# Out:
# ‎sticker omitted                                           18111
# Ok                                                          1285
# Haha                                                         916
# :(                                                           510
# Hahaha                                                       489
#                                                            ...
# Helllo 😆                                                       1
# I know, cause I miss you too                                   1
# Ok i go back                                                   1
# So pay for what you get lor                                    1
# If u wanna do some shopping, can go furniture shopping😁        1
# Name: msg, Length: 70280, dtype: int64

# %%
chat.shape
# Out:
# (117488, 6)

# %%
chat.describe()
# Out:
#                index
# count  117488.000000
# mean    60495.519338
# std     35027.224256
# min         1.000000
# 25%     30157.750000
# 50%     60464.500000
# 75%     90772.250000
# max    121324.000000

# %%
party_names = chat['name'].unique().tolist()
party_names
# Out:
# ['A.', '👻']

# %%
party_1 = party_names[0]
party_2 = party_names[1]
print(party_1)
print(party_2)
# Out:
# A.
# 👻

# %%
msgcount_1 = chat[chat['name']==party_1]['msg'].count()
msgcount_2 = chat[chat['name']==party_2]['msg'].count()
print(f'Message Count by {party_1}: {msgcount_1}')
print(f'Message Count by {party_2}: {msgcount_2}')
# Out:
# Message Count by A.: 69412
# Message Count by 👻: 48076

# %% [markdown]
# # Text Preprocessing

# %%
def remove_html(text):
    soup = BeautifulSoup(text,'lxml')
    html_free = soup.get_text()
    return html_free

def remove_punctuations(text):
    punc_free = "".join([w for w in text if w not in string.punctuation])
    #punc_free = text.strip('\u200e')
    return punc_free

def tokenize_text(text):
    tokenizer = RegexpTokenizer(r'\w+')
    return tokenizer.tokenize(text)

def word_lemmatizer(text):
    lemmatizer = WordNetLemmatizer()
    lemmatized = [lemmatizer.lemmatize(w) for w in text]
    return lemmatized

# Add stopwords here.
newStopWords = ['sticker','omitted']
stop_list = text.ENGLISH_STOP_WORDS.union(newStopWords)

def remove_stopwords(text):
    words = [w for w in text if w not in stop_list]
    return words

# %%
len(stops)
# Out:
# 320

# %%
chat['msg_cleaned'] = chat['msg'].apply(lambda x: remove_punctuations(x)).apply(lambda x: remove_html(x))
chat.head()
# Out:
#    index            datetime name  \
# 0      1 2018-03-21 09:47:16   A.
# 1      2 2018-03-21 10:03:35    👻
# 2      3 2018-04-12 11:19:34   A.
# 3      4 2018-04-12 11:19:36   A.
# 4      5 2018-04-12 11:20:25    👻
#
#                                                  msg        date conv_name  \
# 0        Hello 👋 where have you been? You fell sick?  2018-03-21
# 1  Hello, just taking some time off :) need to cl...  2018-03-21
# 2                     Hey! What time is lunch later?  2018-04-12
# 3                                              12pm?  2018-04-12
# 4                                               Yeap  2018-04-12
#
#                                          msg_cleaned
# 0          Hello 👋 where have you been You fell sick
# 1  Hello just taking some time off  need to clear...
# 2                       Hey What time is lunch later
# 3                                               12pm
# 4                                               Yeap

# %%
chat['msg_token']= chat['msg_cleaned'].apply(lambda x: tokenize_text(x)).apply(lambda x: remove_stopwords(x)).apply(lambda x: word_lemmatizer(x))

# %%
#chat.head(10)

# %%
chat[chat['msg'].str.contains('sticker omitted')]['msg'][1587]
# Out:
# '\u200esticker omitted'

# %%
for i in chat['msg']:
    re.sub(r"\\u200e","",i)
    i.replace(r"\\u200e","")

# %%
chat[chat['msg'].str.contains('sticker omitted')]['msg'][1587]
# Out:
# '\u200esticker omitted'

# %%
chat['msg_len']=chat['msg_cleaned'].map(lambda x: len(set(x.split())))
chat.head()
# Out:
#    index            datetime name  \
# 0      1 2018-03-21 09:47:16   A.
# 1      2 2018-03-21 10:03:35    👻
# 2      3 2018-04-12 11:19:34   A.
# 3      4 2018-04-12 11:19:36   A.
# 4      5 2018-04-12 11:20:25    👻
#
#                                                  msg        date conv_name  \
# 0        Hello 👋 where have you been? You fell sick?  2018-03-21
# 1  Hello, just taking some time off :) need to cl...  2018-03-21
# 2                     Hey! What time is lunch later?  2018-04-12
# 3                                              12pm?  2018-04-12
# 4                                               Yeap  2018-04-12
#
#                                          msg_cleaned  \
# 0          Hello 👋 where have you been You fell sick
# 1  Hello just taking some time off  need to clear...
# 2                       Hey What time is lunch later
# 3                                               12pm
# 4                                               Yeap
#
#                                            msg_token  msg_len
# 0                           [Hello, You, fell, sick]        9
# 1  [Hello, just, taking, time, need, clear, leave...       13
# 2                    [Hey, What, time, lunch, later]        6
# 3                                             [12pm]        1
# 4                                             [Yeap]        1

# %% [markdown]
# ### Emoji Extraction

# %%
import emoji
def extract_emojis(str):
    return ''.join(c for c in str if c in emoji.UNICODE_EMOJI)

# %%
chat['emoji']=chat['msg_cleaned'].apply(lambda x: extract_emojis(x))
chat['emoji_count']=chat['emoji'].apply(lambda x: len(x))

# %%
chat.head()
# Out:
#    index            datetime name  \
# 0      1 2018-03-21 09:47:16   A.
# 1      2 2018-03-21 10:03:35    👻
# 2      3 2018-04-12 11:19:34   A.
# 3      4 2018-04-12 11:19:36   A.
# 4      5 2018-04-12 11:20:25    👻
#
#                                                  msg        date conv_name  \
# 0        Hello 👋 where have you been? You fell sick?  2018-03-21
# 1  Hello, just taking some time off :) need to cl...  2018-03-21
# 2                     Hey! What time is lunch later?  2018-04-12
# 3                                              12pm?  2018-04-12
# 4                                               Yeap  2018-04-12
#
#                                          msg_cleaned  \
# 0          Hello 👋 where have you been You fell sick
# 1  Hello just taking some time off  need to clear...
# 2                       Hey What time is lunch later
# 3                                               12pm
# 4                                               Yeap
#
#                                            msg_token  msg_len emoji  \
# 0                           [Hello, You, fell, sick]        9     👋
# 1  [Hello, just, taking, time, need, clear, leave...       13
# 2                    [Hey, What, time, lunch, later]        6
# 3                                             [12pm]        1
# 4                                             [Yeap]        1
#
#    emoji_count
# 0            1
# 1            0
# 2            0
# 3            0
# 4            0

# %%
#chat.drop(columns='emoji',inplace=True)

# %% [markdown]
# ### Sticker Count

# %%
chat["msg"]= chat["msg"].astype(str)

# %% [markdown]
# Could improve below code in order for me to better classify 'sticker_count' based on the party involved.
# ie. if 'sticker omitted' is sent by party 1, then we assign the total number of stickers to the last party's conversation.
# We will ignore this feature for now.

# %%
# build column for sticker counts after message 
sticker_count = []
msg_index = 0
for index, row in chat.iterrows(): # iterating over df rows
    flag = True
    count = 0
    # when a sticker row is encountered, just put 0 in the count column
    # when a non-sticker row is encountered do the following
    if row['msg_cleaned'] != '\u200esticker omitted': 
        k = 1 # to check rows after the non-sticker row
        while flag:
            #print(f'i{msg_index} flag{flag} len{len(chat)}')
            # if the index + k row is a sticker increase the count for index and k
            msg_index=index + k 
            if msg_index >= len(chat):
                break
            if chat.loc[msg_index].msg_cleaned == '\u200esticker omitted': 
                count += 1
                k += 1
                # when reached the end of the database, break the loop
                if msg_index +1 > len(chat):
                    flag = False
                    #print(f'i{msg_index} flag{flag}')
            else:
                flag = False
                k = 1                
    sticker_count.append(count)
chat['sticker_count'] = sticker_count

# %%
chat[chat['msg'].str.contains('sticker omitted')]['msg'][1587]
# Out:
# '\u200esticker omitted'

# %%
chat.tail(25)
# Out:
#          index            datetime name  \
# 117463  121297 2020-09-21 22:37:03   A.
# 117464  121298 2020-09-21 22:39:48   A.
# 117465  121299 2020-09-21 22:43:29   A.
# 117466  121300 2020-09-21 22:57:05    👻
# 117467  121301 2020-09-21 22:57:13    👻
# 117468  121302 2020-09-21 22:57:54   A.
# 117469  121303 2020-09-21 22:58:05    👻
# 117470  121304 2020-09-21 22:58:09   A.
# 117471  121305 2020-09-21 22:58:16    👻
# 117472  121306 2020-09-21 22:58:24   A.
# 117473  121307 2020-09-21 22:58:37   A.
# 117474  121308 2020-09-21 22:58:44   A.
# 117475  121309 2020-09-21 22:58:48   A.
# 117476  121310 2020-09-21 23:02:09    👻
# 117477  121311 2020-09-21 23:02:11    👻
# 117478  121312 2020-09-21 23:02:18   A.
# 117479  121313 2020-09-21 23:02:22   A.
# 117480  121314 2020-09-21 23:03:16    👻
# 117481  121315 2020-09-21 23:03:21   A.
# 117482  121316 2020-09-21 23:04:39   A.
# 117483  121317 2020-09-21 23:04:40   A.
# 117484  121321 2020-09-22 13:36:59   A.
# 117485  121322 2020-09-22 13:37:01   A.
# 117486  121323 2020-09-22 13:37:04   A.
# 117487  121324 2020-09-22 13:41:32    👻
#
#                                              msg        date conv_name  \
# 117463                                  This too  2020-09-21
# 117464                Dearie dont be angry♥️♥️😁😁  2020-09-21
# 117465                          ‎sticker omitted  2020-09-21
# 117466                          ‎sticker omitted  2020-09-21
# 117467                        Wherefore art thou  2020-09-21
# 117468                     I art thou em are tee  2020-09-21
# 117469                          ‎sticker omitted  2020-09-21
# 117470                          ‎sticker omitted  2020-09-21
# 117471                              Where is you  2020-09-21
# 117472                               I is in mrt  2020-09-21
# 117473                          ‎sticker omitted  2020-09-21
# 117474            Do thou get a fetch from thee?  2020-09-21
# 117475                          ‎sticker omitted  2020-09-21
# 117476                          ‎sticker omitted  2020-09-21
# 117477                                        No  2020-09-21
# 117478                         No ride from thee  2020-09-21
# 117479                       Thou shall go ahead  2020-09-21
# 117480                          ‎sticker omitted  2020-09-21
# 117481                          ‎sticker omitted  2020-09-21
# 117482            Dearie coming home to you soon  2020-09-21
# 117483                          ‎sticker omitted  2020-09-21
# 117484  Alyse is a girlfriend, who is cornelius?  2020-09-22
# 117485                          ‎sticker omitted  2020-09-22
# 117486                          ‎sticker omitted  2020-09-22
# 117487                                         ?  2020-09-22
#
#                                    msg_cleaned  \
# 117463                                This too
# 117464              Dearie dont be angry♥️♥️😁😁
# 117465                        ‎sticker omitted
# 117466                        ‎sticker omitted
# 117467                      Wherefore art thou
# 117468                   I art thou em are tee
# 117469                        ‎sticker omitted
# 117470                        ‎sticker omitted
# 117471                            Where is you
# 117472                             I is in mrt
# 117473                        ‎sticker omitted
# 117474           Do thou get a fetch from thee
# 117475                        ‎sticker omitted
# 117476                        ‎sticker omitted
# 117477                                      No
# 117478                       No ride from thee
# 117479                     Thou shall go ahead
# 117480                        ‎sticker omitted
# 117481                        ‎sticker omitted
# 117482          Dearie coming home to you soon
# 117483                        ‎sticker omitted
# 117484  Alyse is a girlfriend who is cornelius
# 117485                        ‎sticker omitted
# 117486                        ‎sticker omitted
# 117487
#
#                              msg_token  msg_len emoji  emoji_count  \
# 117463                          [This]        2                  0
# 117464           [Dearie, dont, angry]        4  ♥♥😁😁            4
# 117465                              []        2                  0
# 117466                              []        2                  0
# 117467          [Wherefore, art, thou]        3                  0
# 117468         [I, art, thou, em, tee]        6                  0
# 117469                              []        2                  0
# 117470                              []        2                  0
# 117471                         [Where]        3                  0
# 117472                        [I, mrt]        4                  0
# 117473                              []        2                  0
# 117474         [Do, thou, fetch, thee]        7                  0
# 117475                              []        2                  0
# 117476                              []        2                  0
# 117477                            [No]        1                  0
# 117478                [No, ride, thee]        4                  0
# 117479            [Thou, shall, ahead]        4                  0
# 117480                              []        2                  0
# 117481                              []        2                  0
# 117482    [Dearie, coming, home, soon]        6                  0
# 117483                              []        2                  0
# 117484  [Alyse, girlfriend, cornelius]        6                  0
# 117485                              []        2                  0
# 117486                              []        2                  0
# 117487                              []        0                  0
#
#         sticker_count
# 117463              0
# 117464              2
# 117465              0
# 117466              0
# 117467              0
# 117468              2
# 117469              0
# 117470              0
# 117471              0
# 117472              1
# 117473              0
# 117474              2
# 117475              0
# 117476              0
# 117477              0
# 117478              0
# 117479              2
# 117480              0
# 117481              0
# 117482              1
# 117483              0
# 117484              2
# 117485              0
# 117486              0
# 117487              0

# %%
chat.shape
# Out:
# (117488, 12)

# %%
chat = chat[~chat['msg'].str.contains('sticker omitted')]
chat.shape
# Out:
# (99377, 12)

# %%
chat.to_csv('data/data_code/sample_1_cleaned.csv', index = False)

# %% [markdown]
# ## Data Visualisation

# %%
msg_1 = chat[chat['name']==party_1]
msg_2 = chat[chat['name']==party_2]

# %%
chat.groupby(['date']).count()['msg'].plot(figsize=(17,7),title=f'Message Frequency');

# %%
def chat_filter_date(df):
    start_date = parser.parse(input("Enter start date: "))
    end_date = parser.parse(input("Enter end date: "))
    df_filtered = df.filter_date('date',start_date, end_date)[['date','name','msg']]
    return df_filtered.head(10)

# %%
#chat_filter_date(chat)

# %%
chat.groupby(['date'])['msg_len'].mean().plot(figsize=(17,7),title=f'Length of Messages');

# %%
chat.groupby(['date'])['emoji_count'].mean().plot(figsize=(17,7),title=f'Number of Emojis');

# %%
chat.groupby(['date'])['emoji_count'].mean().sort_values(ascending=False)
# Out:
# date
# 2019-02-12    37.45481
# 2019-02-25     1.22560
# 2020-05-05     1.00000
# 2020-06-29     0.80000
# 2018-03-21     0.50000
#                 ...
# 2020-06-04     0.00000
# 2020-06-06     0.00000
# 2020-06-07     0.00000
# 2020-06-09     0.00000
# 2020-09-22     0.00000
# Name: emoji_count, Length: 680, dtype: float64

# %%
def chat_filter_emoji(df):
    lower = int(input("Enter Emoji Lower Range: ") or 0)
    upper = int(input("Enter Emoji Upper Range: ") or df['emoji_count'].max())
    
    df_filtered = chat[(chat['emoji_count'] < upper) & (chat['emoji_count'] > lower)][['date','name','msg','emoji_count']].sort_values(by='emoji_count',ascending=False)
    return df_filtered.head(10)

# %%
chat_filter_emoji(chat)
# Out:
# Enter Emoji Lower Range:
# Enter Emoji Upper Range:
#              date name                                                msg  \
# 13399  2019-02-12   A.  ♥️♥️♥️♥️♥️♥️♥️♥️♥️♥️♥️♥️♥️♥️♥️♥️♥️♥️♥️♥️♥️♥️♥️...
# 18394  2019-02-25    👻  🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱...
# 18387  2019-02-25    👻                  🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱🐱
# 22966  2019-03-13   A.       Dont want to work😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭
# 91055  2020-01-01   A.  I love you and i will have a happy and sweet s...
# 97448  2020-01-28   A.       ☺️☺️☺️☺️☺️☺️☺️☺️☺️☺️☺️☺️☺️☺️☺️☺️☺️☺️☺️☺️☺️☺️
# 30166  2019-04-16   A.   Love you so much☺️☺️☺️☺️☺️☺️☺️☺️☺️☺️☺️☺️☺️☺️☺️☺️
# 90722  2019-12-30   A.   Lemme know when u wanna check out 🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰
# 13987  2019-02-14   A.               Cant wait for saturday🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰
# 82357  2019-11-23   A.            dear wake ip👩‍👦👩‍❤️‍💋‍👩👩‍❤️‍💋‍👩👩‍❤️‍💋‍👩
#
#        emoji_count
# 13399         3200
# 18394          656
# 18387           33
# 22966           27
# 91055           25
# 97448           22
# 30166           16
# 90722           14
# 13987           14
# 82357           14

# %%
chat.groupby(['date'])['sticker_count'].mean().plot(figsize=(17,7),title=f'Number of Stickers');

# %%
def chat_filter_sticker(df):
    lower = int(input("Enter Sticker Lower Range: ") or 0)
    upper = int(input("Enter Sticker Upper Range: ") or df['sticker_count'].max())
    
    df_filtered = chat[(chat['sticker_count'] < upper) & (chat['sticker_count'] > lower)][['date','name','msg','sticker_count']].sort_values(by='sticker_count',ascending=False)
    return df_filtered.head(10)

# %%
chat_filter_sticker(chat)
# Out:
# Enter Sticker Lower Range:
# Enter Sticker Upper Range:
#               date name                                                msg  \
# 111710  2020-06-28   A.                                           so angry
# 96110   2020-01-21   A.                                         NOT ON CAB
# 100922  2020-02-16    👻                                         Poop queen
# 111634  2020-06-28    👻                                                 Ok
# 96150   2020-01-21   A.   ‎Location: https://maps.google.com/?q=1.39528...
# 110236  2020-05-06   A.                                Extension cord!!!!!
# 111667  2020-06-28   A.                                           So angry
# 36164   2019-05-10   A.                                    Going to office
# 101560  2020-02-24   A.                                               Helo
# 98516   2020-01-31   A.                              U had a heaet attack?
#
#         sticker_count
# 111710             68
# 96110              39
# 100922             37
# 111634             32
# 96150              31
# 110236             31
# 111667             29
# 36164              28
# 101560             28
# 98516              26

# %% [markdown]
# ## Vectorizing

# %%
cvec = CountVectorizer(stop_words = stop_list)

# %% [markdown]
# ### N-gram = 1

# %%
cvec_msg = cvec.fit_transform(chat['msg_cleaned'])
cvec_msg = pd.DataFrame(cvec_msg.toarray(), columns = cvec.get_feature_names())

# %%
cvec_msg_words = cvec_msg.sum().sort_values(ascending=False)
cvec_msg_words.head(10)
# Out:
# dear     4128
# ok       3116
# im       2816
# just     2280
# want     2182
# haha     2057
# think    1880
# like     1815
# love     1801
# dont     1718
# dtype: int64

# %% [markdown]
# ### N-gram = 2/3

# %%
cvec23 = CountVectorizer(stop_words = stop_list,
                         ngram_range=(2,3),
                        max_features=10000)

# %%
cvec_msg_23 = cvec23.fit_transform(chat['msg_cleaned'])
cvec_msg_23 = pd.DataFrame(cvec_msg_23.toarray(), columns = cvec23.get_feature_names())

# %%
cvec_msg_words_23 = cvec_msg_23.sum().sort_values(ascending=False)
cvec_msg_words_23.head(10)
# Out:
# dear dear     374
# dont want     219
# feel like     212
# don know      185
# dont know     137
# silly girl    136
# yes mdm       135
# dont think    133
# rly rly        99
# don want       95
# dtype: int64

# %%
from matplotlib.colors import LinearSegmentedColormap
colors = ["#000000", "#111111", "#101010", "#121212", "#212121", "#222222"]
cmap = LinearSegmentedColormap.from_list("mycmap", colors)

msg_1 = WordCloud(width = 1200, height = 900, background_color ='white',
                  colormap=cmap).generate_from_frequencies(cvec_msg_words) 

msg_23 = WordCloud(width = 1200, height = 900, background_color ='white',
                  colormap=cmap).generate_from_frequencies(cvec_msg_words_23)

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (15, 10))
ax[0].imshow(msg_1)
ax[1].imshow(msg_23)

ax[0].set_title('N-gram = 1',size=15)
ax[1].set_title('N-gram = 2/3',size=15)

ax[0].axis('off')
ax[1].axis('off')

plt.tight_layout(pad=5)
