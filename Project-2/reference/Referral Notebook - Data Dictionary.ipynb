# %% [markdown]
# # DATA DICTIONARY

# %% [markdown]
# ### Identification
# 0. Id (integer)
# 1. PID (integer)
#
# ### Independent Variables (x-variables):
# 2. MSSubClass (integer): The building class
#     - 20 1-STORY 1946 & NEWER ALL STYLES
#     - 30 1-STORY 1945 & OLDER
#     - 40 1-STORY W/FINISHED ATTIC ALL AGES
#     - 45 1-1/2 STORY - UNFINISHED ALL AGES
#     - 50 1-1/2 STORY FINISHED ALL AGES
#     - 60 2-STORY 1946 & NEWER
#     - 70 2-STORY 1945 & OLDER
#     - 75 2-1/2 STORY ALL AGES
#     - 80 SPLIT OR MULTI-LEVEL
#     - 85 SPLIT FOYER
#     - 90 DUPLEX - ALL STYLES AND AGES
#     - 120 1-STORY PUD (Planned Unit Development) - 1946 & NEWER
#     - 150 1-1/2 STORY PUD - ALL AGES
#     - 160 2-STORY PUD - 1946 & NEWER
#     - 180 PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
#     - 190 2 FAMILY CONVERSION - ALL STYLES AND AGES
# 3. MSZoning (string): Identifies the general zoning classification of the sale.
#     - A Agriculture
#     - C Commercial
#     - FV Floating Village Residential
#     - I Industrial
#     - RH Residential High Density
#     - RL Residential Low Density
#     - RP Residential Low Density Park
#     - RM Residential Medium Density
# 4. LotFrontage (float): Linear feet of street connected to property
# 5. LotArea (integer): Lot size in square feet
# 6. Street (string): Type of road access to property
#     - Grvl Gravel
#     - Pave Paved
# 7. Alley (string): Type of alley access to property
#     - Grvl Gravel
#     - Pave Paved
#     - NA No alley access
# 8. LotShape(string): General shape of property
#     - Reg Regular
#     - IR1 Slightly irregular
#     - IR2 Moderately Irregular
#     - IR3 Irregular
# 9. LandContour (string): Flatness of the property
#     - Lvl Near Flat/Level
#     - Bnk Banked - Quick and significant rise from street grade to building
#     - HLS Hillside - Significant slope from side to side
#     - Low Depression
# 10. Utilities: Type of utilities available
#     - AllPub All public Utilities (E,G,W,& S)
#     - NoSewr Electricity, Gas, and Water (Septic Tank)
#     - NoSeWa Electricity and Gas Only
#     - ELO Electricity only
# 13. LotConfig (string): Lot configuration
#     - Inside Inside lot
#     - Corner Corner lot
#     - CulDSac Cul-de-sac
#     - FR2 Frontage on 2 sides of property
#     - FR3 Frontage on 3 sides of property
# 12. LandSlope (string): Slope of property
#     - Gtl Gentle slope
#     - Mod Moderate Slope
#     - Sev Severe Slope
# 14. Neighborhood (string): Physical locations within Ames city limits
#     - Blmngtn Bloomington Heights
#     - Blueste Bluestem
#     - BrDale Briardale
#     - BrkSide Brookside
#     - ClearCr Clear Creek
#     - CollgCr College Creek
#     - Crawfor Crawford
#     - Edwards Edwards
#     - Gilbert Gilbert
#     - IDOTRR Iowa DOT and Rail Road
#     - MeadowV Meadow Village
#     - Mitchel Mitchell
#     - Names North Ames
#     - NoRidge Northridge
#     - NPkVill Northpark Villa
#     - NridgHt Northridge Heights
#     - NWAmes Northwest Ames
#     - OldTown Old Town
#     - SWISU South & West of Iowa State University
#     - Sawyer Sawyer
#     - SawyerW Sawyer West
#     - Somerst Somerset
#     - StoneBr Stone Brook
#     - Timber Timberland
#     - Veenker Veenker
# 15. Condition1 (string): Proximity to main road or railroad
#     - Artery Adjacent to arterial street
#     - Feedr Adjacent to feeder street
#     - Norm Normal
#     - RRNn Within 200' of North-South Railroad
#     - RRAn Adjacent to North-South Railroad
#     - PosN Near positive off-site feature--park, greenbelt, etc.
#     - PosA Adjacent to postive off-site feature
#     - RRNe Within 200' of East-West Railroad
#     - RRAe Adjacent to East-West Railroad
# 16. Condition2 (string): Proximity to main road or railroad (if a second is present)
#     - Artery Adjacent to arterial street
#     - Feedr Adjacent to feeder street
#     - Norm Normal
#     - RRNn Within 200' of North-South Railroad
#     - RRAn Adjacent to North-South Railroad
#     - PosN Near positive off-site feature--park, greenbelt, etc.
#     - PosA Adjacent to postive off-site feature
#     - RRNe Within 200' of East-West Railroad
#     - RRAe Adjacent to East-West Railroad
# 17. BldgType (string): Type of dwelling
#     - 1Fam Single-family Detached
#     - 2FmCon Two-family Conversion; originally built as one-family dwelling
#     - Duplx Duplex
#     - TwnhsE Townhouse End Unit
#     - TwnhsI Townhouse Inside Unit
# 18. HouseStyle (string): Style of dwelling
#     - 1Story One story
#     - 1.5Fin One and one-half story: 2nd level finished
#     - 1.5Unf One and one-half story: 2nd level unfinished
#     - 2Story Two story
#     - 2.5Fin Two and one-half story: 2nd level finished
#     - 2.5Unf Two and one-half story: 2nd level unfinished
#     - SFoyer Split Foyer
#     - SLvl Split Level
# 19. OverallQual (integer): Overall material and finish quality
#     - 10 Very Excellent
#     - 9 Excellent
#     - 8 Very Good
#     - 7 Good
#     - 6 Above Average
#     - 5 Average
#     - 4 Below Average
#     - 3 Fair
#     - 2 Poor
#     - 1 Very Poor
# 20. OverallCond (integer): Overall condition rating
#     - 10 Very Excellent
#     - 9 Excellent
#     - 8 Very Good
#     - 7 Good
#     - 6 Above Average
#     - 5 Average
#     - 4 Below Average
#     - 3 Fair
#     - 2 Poor
#     - 1 Very Poor
# 23. YearBuilt (integer): Original construction date
# 22. YearRemodAdd (integer): Remodel date (same as construction date if no remodeling or additions)
# 23. RoofStyle (string): Type of roof
#     - Flat Flat
#     - Gable Gable
#     - Gambrel Gabrel (Barn)
#     - Hip Hip
#     - Mansard Mansard
#     - Shed Shed
# 24. RoofMatl (string): Roof material
#     -     - ClyTile Clay or Tile
#     - CompShg Standard (Composite) Shingle
#     - Membran Membrane
#     - Metal Metal
#     - Roll Roll
#     - Tar&Grv Gravel & Tar
#     - WdShake Wood Shakes
#     - WdShngl Wood Shingles
# 25. Exterior1st (string): Exterior covering on house
#     - AsbShng Asbestos Shingles
#     - AsphShn Asphalt Shingles
#     - BrkComm Brick Common
#     - BrkFace Brick Face
#     - CBlock Cinder Block
#     -     - CemntBd Cement Board
#     - HdBoard Hard Board
#     - ImStucc Imitation Stucco
#     - MetalSd Metal Siding
#     - Other Other
#     - Plywood Plywood
#     - PreCast PreCast
#     - Stone Stone
#     - Stucco Stucco
#     - VinylSd Vinyl Siding
#     - Wd Sdng Wood Siding
#     - WdShing Wood Shingles
# 26. Exterior2nd (string): Exterior covering on house (if more than one material)
#     - AsbShng Asbestos Shingles
#     - AsphShn Asphalt Shingles
#     - BrkComm Brick Common
#     - BrkFace Brick Face
#     - CBlock Cinder Block
#     - CemntBd Cement Board
#     - HdBoard Hard Board
#     - ImStucc Imitation Stucco
#     - MetalSd Metal Siding
#     - Other Other
#     - Plywood Plywood
#     - PreCast PreCast
#     - Stone Stone
#     - Stucco Stucco
#     - VinylSd Vinyl Siding
#     - Wd Sdng Wood Siding
#     - WdShing Wood Shingles
# 27. MasVnrType (string): Masonry veneer type
#     - BrkCmn Brick Common
#     - BrkFace Brick Face
#     - CBlock Cinder Block
#     - None None
#     - Stone Stone
# 28. MasVnrArea (Float): Masonry veneer area in square feet
# 29. ExterQual (string): Exterior material quality
#     - Ex Excellent
#     - Gd Good
#     - TA Average/Typical
#     - Fa Fair
#     - Po Poor
# 30. ExterCond (string): Present condition of the material on the exterior
#     - Ex Excellent
#     - Gd Good
#     - TA Average/Typical
#     - Fa Fair
#     - Po Poor
# 33. Foundation (string): Type of foundation
#     - BrkTil Brick & Tile
#     - CBlock Cinder Block
#     - PConc Poured Contrete
#     - Slab Slab
#     - Stone Stone
#     - Wood Wood
# 31. BsmtQual (string): Height of the basement
#     - Ex Excellent (100+ inches)
#     - Gd Good (90-99 inches)
#     - TA Typical (80-89 inches)
#     - Fa Fair (70-79 inches)
#     - Po Poor (<70 inches)
#     - NA No Basement
# 31. BsmtCond (string): General condition of the basement
#     - Ex Excellent
#     - Gd Good
#     - TA Typical - slight dampness allowed
#     - Fa Fair - dampness or some cracking or settling
#     - Po Poor - Severe cracking, settling, or wetness
#     - NA No Basement
# 31. BsmtExposure (string): Walkout or garden level basement walls
#     - Gd Good Exposure
#     - Av Average Exposure (split levels or foyers typically score average or above)
#     - Mn Mimimum Exposure
#     - No No Exposure
#     - NA No Basement
# 31. BsmtFinType1 (string): Quality of basement finished area
#     - GLQ Good Living Quarters
#     - ALQ Average Living Quarters
#     - BLQ Below Average Living Quarters
#     - Rec Average Rec Room
#     - LwQ Low Quality
#     - Unf Unfinshed
#     - NA No Basement
# 31. BsmtFinSF1 (float): Type 1 finished square feet
# 31. BsmtFinType2 (string): Quality of second finished area (if present)
#     - GLQ Good Living Quarters
#     - ALQ Average Living Quarters
#     - BLQ Below Average Living Quarters
#     - Rec Average Rec Room
#     - LwQ Low Quality
#     - Unf Unfinshed
#     - NA No Basement
# 31. BsmtFinSF2 (float): Type 2 finished square feet
# 31. BsmtUnfSF (float): Unfinished square feet of basement area
# 31. TotalBsmtSF (float): Total square feet of basement area
# 43. Heating (string): Type of heating
#     - Floor Floor Furnace
#     - GasA Gas forced warm air furnace
#     - GasW Gas hot water or steam heat
#     - Grav Gravity furnace
#     - OthW Hot water or steam heat other than gas
#     - Wall Wall furnace
# 41. HeatingQC (string): Heating quality and condition
#     - Ex Excellent
#     - Gd Good
#     - TA Average/Typical
#     - Fa Fair
#     - Po Poor
# 41. CentralAir (string): Central air conditioning
#     - N No
#     - Y Yes
# 41. Electrical (string): Electrical system
#     - SBrkr Standard Circuit Breakers & Romex
#     - FuseA Fuse Box over 60 AMP and all Romex wiring (Average)
#     - FuseF 60 AMP Fuse Box and mostly Romex wiring (Fair)
#     - FuseP 60 AMP Fuse Box and mostly knob & tube wiring (poor)
#     - Mix Mixed
# 41. 1stFlrSF (float): First Floor square feet
# 41. 2ndFlrSF (float): Second floor square feet
# 41. LowQualFinSF (float): Low quality finished square feet (all floors)
# 41. GrLivArea (float): Above grade (ground) living area square feet
# 41. BsmtFullBath (integer): Basement full bathrooms
# 41. BsmtHalfBath (integer): Basement half bathrooms
# 41. FullBath (integer): Full bathrooms above grade
# 41. HalfBath (integer): Half baths above grade
# 41. Bedroom AbvGr (integer): Number of bedrooms above basement level
# 41. Kitchen AbvGr (integer): Number of kitchens
# 41. KitchenQual (string): Kitchen quality
#     - Ex Excellent
#     - Gd Good
#     - TA Typical/Average
#     - Fa Fair
#     - Po Poor
# 41. TotRmsAbvGrd (integer): Total rooms above grade (does not include bathrooms)
# 41. Functional (string): Home functionality rating
#     - Typ Typical Functionality
#     - Min1 Minor Deductions 1
#     - Min2 Minor Deductions 2
#     - Mod Moderate Deductions
#     - Maj1 Major Deductions 1
#     - Maj2 Major Deductions 2
#     - Sev Severely Damaged
#     - Sal Salvage only
# 41. Fireplaces (integer): Number of fireplaces
# 41. FireplaceQu (string) : Fireplace quality
#     - Ex Excellent - Exceptional Masonry Fireplace
#     - Gd Good - Masonry Fireplace in main level
#     - TA Average - Prefabricated Fireplace in main living area or Masonry Fireplace in basement
#     - Fa Fair - Prefabricated Fireplace in basement
#     - Po Poor - Ben Franklin Stove
#     - NA No Fireplace
# 41. GarageType (string): Garage location
#     - 2Types More than one type of garage
#     - Attchd Attached to home
#     - Basment Basement Garage
#     - BuiltIn Built-In (Garage part of house - typically has room above garage)
#     - CarPort Car Port
#     - Detchd Detached from home
#     - NA No Garage
# 41. GarageYrBlt (float): Year garage was built
# 41. GarageFinish (string): Interior finish of the garage
#     - Fin Finished
#     - RFn Rough Finished
#     - Unf Unfinished
#     - NA No Garage
# 41. GarageCars (float): Size of garage in car capacity
# 41. GarageArea (float): Size of garage in square feet
# 41. GarageQual (string): Garage quality
#     - Ex Excellent
#     - Gd Good
#     - TA Typical/Average
#     - Fa Fair
#     - Po Poor
#     - NA No Garage
# 41. GarageCond (string): Garage condition
#     - Ex Excellent
#     - Gd Good
#     - TA Typical/Average
#     - Fa Fair
#     - Po Poor
#     - NA No Garage
# 41. PavedDrive (string): Paved driveway
#     - Y Paved
#     - P Partial Pavement
#     - N Dirt/Gravel
# 41. WoodDeckSF (integer): Wood deck area in square feet
# 41. OpenPorchSF (integer): Open porch area in square feet
# 41. EnclosedPorch (integer): Enclosed porch area in square feet
# 41. 3SsnPorch (integer): Three season porch area in square feet
# 41. ScreenPorch (integer): Screen porch area in square feet
# 41. PoolArea (integer): Pool area in square feet
# 41. PoolQC (string): Pool quality
#     - Ex Excellent
#     - Gd Good
#     - TA Average/Typical
#     - Fa Fair
#     - NA No Pool
# 41. Fence (string): Fence quality
#     - GdPrv Good Privacy
#     - MnPrv Minimum Privacy
#     - GdWo Good Wood
#     - MnWw Minimum Wood/Wire
#     - NA No Fence
# 41. MiscFeature (string): Miscellaneous feature not covered in other categories
#     - Elev Elevator
#     - Gar2 2nd Garage (if not described in garage section)
#     - Othr Other
#     - Shed Shed (over 100 SF)
#     - TenC Tennis Court
#     - NA None
# 41. MiscVal (integer): $Value of miscellaneous feature
# 41. MoSold (integer): Month Sold
# 41. YrSold (integer): Year Sold
# 41. SaleType (string): Type of sale
#     - WD Warranty Deed - Conventional
#     - CWD Warranty Deed - Cash
#     - VWD Warranty Deed - VA Loan
#     - New Home just constructed and sold
#     - COD Court Officer Deed/Estate
#     - Con Contract 15% Down payment regular terms
#     - ConLw Contract Low Down payment and low interest
#     - ConLI Contract Low Interest
#     - ConLD Contract Low Down
#     - Oth Other
#
# ### Dependent Variable (To be predicted, y-variable):
# 80. SalePrice (integer) - the property's sale price in dollars.

# %% [markdown]
# ##### Data Cleaning
#
# 5. Data cleaning:
#     - Will be incorporating pool factor into our cleaned data with a boolean indicating if there is a pool or not.
# 6. Data Cleaning:
#     - Will be dropping this column altogether, as there are too many missing values, and the column does not seem important in determining sales price. Moreover, there is only one house with tennis court (which caused an upwards bias in the sales price). (miscfeature column)
# 7. Data Cleaning: To drop column "Alley"
# 8. Data Cleaning: Suggest to drop column. (Lot Frontage)
# 9. Data Cleaning:
#     - To fill missing "bsmtfintype2" value for index 1147 with mode.
#     - To fill missing "bsmtexposure" values for the 3 index with "No".
# 10. Data Cleaning:
#     - To fill missing "masvnrarea" values with 0.
#     - To fill missing "masvnrtype" values with None.
#     - To remove the "masvnrtype" = None values, change to 0.
#     - For area = 0, BrkFace to fill with 254.63015873015874 (#669,#1136)
#       - train[train['masvnrtype']=="BrkFace"].mean()['masvnrarea']
#     - For area = 0, Stone to fill with 230.41071428571428 (#1187)
#       - train[train['masvnrtype']=="Stone"].mean()['masvnrarea']
#     - For type = None, #810, #1832 will be filled with mode: "BrkFace"
# 11. To fill bsmthalfbath and bsmtfullbath to be 0.0
#     - To fill bsmtunfsf,bsmtunfsf2,totlabsmtsf, bsmtfinsf1 for #1327 with 0.0.
# 12. To fill garagecar and garagearea of #1712 with mean of "Detached" garage type.
#     - train[train['garagetype']=="Detchd"].mean()['garagearea']
#     - train[train['garagetype']=="Detchd"].mean()['garagecars']

# %% [markdown]
# Right skewed, positive skewed:
# - lotarea, bsmtfinsf2, lowqualfinsf, miscval, bsmtfintype2,landslope
#
# Sparse data. Perhaps can combined:
# - bsmtfullbath, bsmthalfbath, fullbath, halfbath
#
# Sparse data. Perhaps can combined:
# - enclosedporch, 2snporch, screenporch, openporchsf(most no.)
